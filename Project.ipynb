# %% [markdown]
# # Final Project

# %% [markdown]
# ## Noy Oved - 207654542

# %% [markdown]
# ## Siel Farage - 311360549

# %% [markdown]
# ### Part 1

# %%
import pandas as pd 
import numpy as np 
import matplotlib as mt
import seaborn as sb

# %%
employment_df1 = pd.read_csv("Employment-Fishing sector.csv")
employment2_df=employment_df1.drop(columns=['PowerCode','GENDER','OCCUP_RATE','PowerCode Code','Reference Period Code','Reference Period','Flag Codes','YEAR','COUNTRY','Unit Code','ECO_SECTOR'])

# %% [markdown]
# ### טעינה לפי המדינות, השארת מגדר כולל (לא זכר/נקבה)

# %%
employment_df=employment2_df.loc[(employment2_df.Country == "Australia")|(employment2_df.Country == "Estonia")|(employment2_df.Country == "Finland")|(employment2_df.Country == "Greece")|(employment2_df.Country == "Korea")|(employment2_df.Country == "Latvia")|(employment2_df.Country == "Mexico")|(employment2_df.Country == "Netherlands")|(employment2_df.Country == "Poland")|(employment2_df.Country == "Portugal")|(employment2_df.Country == "Sweden")|(employment2_df.Country == "Turkey")|(employment2_df.Country == "Argentina")|(employment2_df.Country == "Colombia")|(employment2_df.Country == "Indonesia"),:]
employment_df = employment_df.groupby('Gender')
employment_df = employment_df.get_group('Total by Gender')
employment_df.rename({'Value':'Employees_Num'}, axis='columns', inplace=True)
employment_df
# Out:
#         Country             Economic           Gender  \
# 0     Australia       Fishing Sector  Total by Gender
# 1     Australia       Fishing Sector  Total by Gender
# 2     Australia       Fishing Sector  Total by Gender
# 3     Australia       Fishing Sector  Total by Gender
# 4     Australia       Fishing Sector  Total by Gender
# ...         ...                  ...              ...
# 8693   Portugal           Processing  Total by Gender
# 8746     Poland  Unspecified Fishing  Total by Gender
# 8747     Poland  Unspecified Fishing  Total by Gender
# 8748     Poland  Unspecified Fishing  Total by Gender
# 8749     Poland  Unspecified Fishing  Total by Gender
#
#                     Occupation  Year    Unit  Employees_Num Flags
# 0     Total by Occupation rate  2005  Number         7441.0   NaN
# 1     Total by Occupation rate  2006  Number         8235.0   NaN
# 2     Total by Occupation rate  2007  Number         6151.0   NaN
# ...

# %% [markdown]
# ###  השארת טוטאל מספר המועסקים, כלומר ללא התחשבות בחצי משרה\משרה מלאה.

# %%
employment_df=employment_df.loc[(employment_df.Occupation =="Total by Occupation rate")]
employment_df.head()
# Out:
#      Country        Economic           Gender                Occupation  Year  \
# 0  Australia  Fishing Sector  Total by Gender  Total by Occupation rate  2005
# 1  Australia  Fishing Sector  Total by Gender  Total by Occupation rate  2006
# 2  Australia  Fishing Sector  Total by Gender  Total by Occupation rate  2007
# 3  Australia  Fishing Sector  Total by Gender  Total by Occupation rate  2008
# 4  Australia  Fishing Sector  Total by Gender  Total by Occupation rate  2009
#
#      Unit  Employees_Num Flags
# 0  Number         7441.0   NaN
# 1  Number         8235.0   NaN
# 2  Number         6151.0   NaN
# 3  Number         9239.0   NaN
# 4  Number         4469.0   NaN

# %%
employment_df =employment_df.drop(columns=['Gender','Occupation','Flags','Unit'])
employment_df
# Out:
#         Country        Economic  Year  Employees_Num
# 0     Australia  Fishing Sector  2005         7441.0
# 1     Australia  Fishing Sector  2006         8235.0
# 2     Australia  Fishing Sector  2007         6151.0
# 3     Australia  Fishing Sector  2008         9239.0
# 4     Australia  Fishing Sector  2009         4469.0
# ...         ...             ...   ...            ...
# 8689   Portugal      Processing  2011         7447.0
# 8690   Portugal      Processing  2012         7167.0
# 8691   Portugal      Processing  2013         6726.0
# 8692   Portugal      Processing  2014         7068.0
# 8693   Portugal      Processing  2015         7148.0
#
# [864 rows x 4 columns]

# %% [markdown]
# ### הפרדה לתתי סוגי העובדים במשק

# %%
Aquaculture_df=employment_df.loc[(employment_df.Economic == "Aquaculture")]
Aquaculture_df
# Out:
#         Country     Economic  Year  Employees_Num
# 234   Australia  Aquaculture  2005         5811.0
# 235   Australia  Aquaculture  2006         3800.0
# 236   Australia  Aquaculture  2007         3264.0
# 237   Australia  Aquaculture  2008         4132.0
# 238   Australia  Aquaculture  2009         4656.0
# ...         ...          ...   ...            ...
# 8398   Portugal  Aquaculture  2010         2320.0
# 8399   Portugal  Aquaculture  2011         2300.0
# 8400   Portugal  Aquaculture  2012         2431.0
# 8401   Portugal  Aquaculture  2013         2454.0
# 8402   Portugal  Aquaculture  2014         2359.0
#
# [161 rows x 4 columns]

# %%
Fishing_Sector_df=employment_df.loc[(employment_df.Economic == "Fishing Sector")]
Fishing_Sector_df
# Out:
#         Country        Economic  Year  Employees_Num
# 0     Australia  Fishing Sector  2005         7441.0
# 1     Australia  Fishing Sector  2006         8235.0
# 2     Australia  Fishing Sector  2007         6151.0
# 3     Australia  Fishing Sector  2008         9239.0
# 4     Australia  Fishing Sector  2009         4469.0
# ...         ...             ...   ...            ...
# 6956     Latvia  Fishing Sector  2013          701.0
# 6957     Latvia  Fishing Sector  2014          634.0
# 6958     Latvia  Fishing Sector  2015          711.0
# 6959     Latvia  Fishing Sector  2016         1111.0
# 6960     Latvia  Fishing Sector  2017          549.0
#
# [175 rows x 4 columns]

# %%
Inland_Waters_Fishing=employment_df.loc[(employment_df.Economic == "Inland Waters Fishing")]
Inland_Waters_Fishing
# Out:
#       Country               Economic  Year  Employees_Num
# 1305  Finland  Inland Waters Fishing  2005          545.0
# 1306  Finland  Inland Waters Fishing  2006          556.0
# 1307  Finland  Inland Waters Fishing  2007          554.0
# 1308  Finland  Inland Waters Fishing  2008          562.0
# 1309  Finland  Inland Waters Fishing  2009          571.0
# ...       ...                    ...   ...            ...
# 7071   Latvia  Inland Waters Fishing  2013          104.0
# 7072   Latvia  Inland Waters Fishing  2014          121.0
# 7073   Latvia  Inland Waters Fishing  2015          109.0
# 7074   Latvia  Inland Waters Fishing  2016          108.0
# 7075   Latvia  Inland Waters Fishing  2017          112.0
#
# [138 rows x 4 columns]

# %%
Marine_Coastal_Fishing=employment_df.loc[(employment_df.Economic == "Marine Coastal Fishing")]
Marine_Coastal_Fishing
# Out:
#         Country                Economic  Year  Employees_Num
# 1380    Finland  Marine Coastal Fishing  2005         2210.0
# 1381    Finland  Marine Coastal Fishing  2006         2210.0
# 1382    Finland  Marine Coastal Fishing  2007         2074.0
# 1383    Finland  Marine Coastal Fishing  2008         2165.0
# 1384    Finland  Marine Coastal Fishing  2009         2151.0
# ...         ...                     ...   ...            ...
# 8486  Argentina  Marine Coastal Fishing  2013        13884.0
# 8487  Argentina  Marine Coastal Fishing  2014        13929.0
# 8488  Argentina  Marine Coastal Fishing  2015        13866.0
# 8489  Argentina  Marine Coastal Fishing  2016        12791.0
# 8490  Argentina  Marine Coastal Fishing  2017        12979.0
#
# [162 rows x 4 columns]

# %%
Marine_Deep_Sea_Fishing=employment_df.loc[(employment_df.Economic == "Marine Deep-Sea Fishing")]
Marine_Deep_Sea_Fishing
# Out:
#      Country                 Economic  Year  Employees_Num
# 2022  Greece  Marine Deep-Sea Fishing  2005         2633.0
# 2023  Greece  Marine Deep-Sea Fishing  2006         2563.0
# 2024  Greece  Marine Deep-Sea Fishing  2007         4613.0
# 2025  Greece  Marine Deep-Sea Fishing  2008         4593.0
# 2026  Greece  Marine Deep-Sea Fishing  2009         5702.0
# ...      ...                      ...   ...            ...
# 7289  Latvia  Marine Deep-Sea Fishing  2013          470.0
# 7290  Latvia  Marine Deep-Sea Fishing  2014          377.0
# 7291  Latvia  Marine Deep-Sea Fishing  2015          372.0
# 7292  Latvia  Marine Deep-Sea Fishing  2016          871.0
# 7293  Latvia  Marine Deep-Sea Fishing  2017          290.0
#
# [98 rows x 4 columns]

# %%
Processing_df=employment_df.loc[(employment_df.Economic == "Processing")]
Processing_df
# Out:
#        Country    Economic  Year  Employees_Num
# 1488   Finland  Processing  2005          865.0
# 1489   Finland  Processing  2006          824.0
# 1490   Finland  Processing  2007          936.0
# 1491   Finland  Processing  2009          885.0
# 1492   Finland  Processing  2010          870.0
# ...        ...         ...   ...            ...
# 8689  Portugal  Processing  2011         7447.0
# 8690  Portugal  Processing  2012         7167.0
# 8691  Portugal  Processing  2013         6726.0
# 8692  Portugal  Processing  2014         7068.0
# 8693  Portugal  Processing  2015         7148.0
#
# [108 rows x 4 columns]

# %%
Unspecified_Fishing=employment_df.loc[(employment_df.Economic == "Unspecified Fishing")]
Unspecified_Fishing
# Out:
#         Country             Economic  Year  Employees_Num
# 117   Australia  Unspecified Fishing  2005         7441.0
# 118   Australia  Unspecified Fishing  2006         8235.0
# 119   Australia  Unspecified Fishing  2007         6151.0
# 120   Australia  Unspecified Fishing  2008         9239.0
# 121   Australia  Unspecified Fishing  2009         4469.0
# 122   Australia  Unspecified Fishing  2010         7801.0
# 123   Australia  Unspecified Fishing  2011         7403.0
# 124   Australia  Unspecified Fishing  2012         7057.0
# 125   Australia  Unspecified Fishing  2013         6008.0
# 126   Australia  Unspecified Fishing  2014         3561.0
# 127   Australia  Unspecified Fishing  2015         7183.0
# 128   Australia  Unspecified Fishing  2016         5602.0
# 129   Australia  Unspecified Fishing  2017         7593.0
# 3417     Mexico  Unspecified Fishing  2005        43007.0
# 8342     Poland  Unspecified Fishing  2010         1409.0
# ...

# %% [markdown]
# ### טעינת קובץ חדש של אורך קווי החוף

# %%
def standardNormalization(data):
    standardized = (data-data.mean())/data.std()
    return pd.Series(standardized)

# %%
cosatline_df= pd.read_csv("Coastline.csv")
cosatline_df
# Out:
#         Country  Coastline
# 0       Austria          0
# 1         Chile       6435
# 2       Estonia       3794
# 3       Finland       1250
# 4        Greece      13676
# 5         Korea       8460
# 6        Latvia        531
# 7        Mexico       9330
# 8   Netherlands        451
# 9        Poland        770
# 10     Portugal       1790
# 11       Sweden          0
# 12       Turkey       7200
# 13    Argentina       4989
# 14     Colombia       3200
# 15    Indonesia      54720
# 16    Australia      59736

# %% [markdown]
# #### נרמול פיצ'ר של אורך קווי החוף

# %%
x = cosatline_df.Coastline
cosatline_df['Coastline'] = standardNormalization(x)
cosatline_df
# Out:
#         Country  Coastline
# 0       Austria  -0.573822
# 1         Chile  -0.217827
# 2       Estonia  -0.363931
# 3       Finland  -0.504670
# 4        Greece   0.182756
# 5         Korea  -0.105801
# 6        Latvia  -0.544446
# 7        Mexico  -0.057671
# 8   Netherlands  -0.548871
# 9        Poland  -0.531224
# 10     Portugal  -0.474796
# 11       Sweden  -0.573822
# 12       Turkey  -0.175506
# 13    Argentina  -0.297822
# 14     Colombia  -0.396792
# 15    Indonesia   2.453376
# 16    Australia   2.730869

# %%
cosatline_df.rename({'Coastline':'Coastline_std'}, axis='columns', inplace=True)
cosatline_df
# Out:
#         Country  Coastline_std
# 0       Austria      -0.573822
# 1         Chile      -0.217827
# 2       Estonia      -0.363931
# 3       Finland      -0.504670
# 4        Greece       0.182756
# 5         Korea      -0.105801
# 6        Latvia      -0.544446
# 7        Mexico      -0.057671
# 8   Netherlands      -0.548871
# 9        Poland      -0.531224
# 10     Portugal      -0.474796
# 11       Sweden      -0.573822
# 12       Turkey      -0.175506
# 13    Argentina      -0.297822
# 14     Colombia      -0.396792
# 15    Indonesia       2.453376
# 16    Australia       2.730869

# %% [markdown]
# #### merge
# #### בין כל טבלה שיצרנו קודם לטבלת חופי המדינה, למעשה כעת לטבלאות שעשינו קודם יש עמודה נוספת של אורך קו החוף

# %%
employment_Aquaculture = pd.merge(cosatline_df, Aquaculture_df, on=['Country'])
employment_Aquaculture
# Out:
#        Country  Coastline_std     Economic  Year  Employees_Num
# 0      Estonia      -0.363931  Aquaculture  2006           95.0
# 1      Estonia      -0.363931  Aquaculture  2007           90.0
# 2      Estonia      -0.363931  Aquaculture  2008           96.0
# 3      Estonia      -0.363931  Aquaculture  2009          118.0
# 4      Estonia      -0.363931  Aquaculture  2010           89.0
# ..         ...            ...          ...   ...            ...
# 156  Australia       2.730869  Aquaculture  2013         3298.0
# 157  Australia       2.730869  Aquaculture  2014         5102.0
# 158  Australia       2.730869  Aquaculture  2015         7035.0
# 159  Australia       2.730869  Aquaculture  2016         5364.0
# 160  Australia       2.730869  Aquaculture  2017         8361.0
#
# [161 rows x 5 columns]

# %%
employment_Fishing_Sector = pd.merge(cosatline_df, Fishing_Sector_df, on=['Country'])
employment_Fishing_Sector
# Out:
#        Country  Coastline_std        Economic  Year  Employees_Num
# 0      Estonia      -0.363931  Fishing Sector  2006         4010.0
# 1      Estonia      -0.363931  Fishing Sector  2007         4181.0
# 2      Estonia      -0.363931  Fishing Sector  2008         3788.0
# 3      Estonia      -0.363931  Fishing Sector  2009         2812.0
# 4      Estonia      -0.363931  Fishing Sector  2010         2977.0
# ..         ...            ...             ...   ...            ...
# 170  Australia       2.730869  Fishing Sector  2013         6008.0
# 171  Australia       2.730869  Fishing Sector  2014         3561.0
# 172  Australia       2.730869  Fishing Sector  2015         7183.0
# 173  Australia       2.730869  Fishing Sector  2016         5602.0
# 174  Australia       2.730869  Fishing Sector  2017         7593.0
#
# [175 rows x 5 columns]

# %%
employment_Inland_Waters_Fishing = pd.merge(cosatline_df, Inland_Waters_Fishing, on=['Country'])
employment_Inland_Waters_Fishing
# Out:
#        Country  Coastline_std               Economic  Year  Employees_Num
# 0      Estonia      -0.363931  Inland Waters Fishing  2006          963.0
# 1      Estonia      -0.363931  Inland Waters Fishing  2007          701.0
# 2      Estonia      -0.363931  Inland Waters Fishing  2008          596.0
# 3      Estonia      -0.363931  Inland Waters Fishing  2009          675.0
# 4      Estonia      -0.363931  Inland Waters Fishing  2010          771.0
# ..         ...            ...                    ...   ...            ...
# 133  Indonesia       2.453376  Inland Waters Fishing  2011       489965.0
# 134  Indonesia       2.453376  Inland Waters Fishing  2012       470520.0
# 135  Indonesia       2.453376  Inland Waters Fishing  2013       475126.0
# 136  Indonesia       2.453376  Inland Waters Fishing  2014       529688.0
# 137  Indonesia       2.453376  Inland Waters Fishing  2015       427525.0
#
# [138 rows x 5 columns]

# %%
employment_Marine_Coastal_Fishing = pd.merge(cosatline_df, Marine_Coastal_Fishing, on=['Country'])
employment_Marine_Coastal_Fishing
# Out:
#        Country  Coastline_std                Economic  Year  Employees_Num
# 0      Estonia      -0.363931  Marine Coastal Fishing  2006         2572.0
# 1      Estonia      -0.363931  Marine Coastal Fishing  2007         3010.0
# 2      Estonia      -0.363931  Marine Coastal Fishing  2008         2727.0
# 3      Estonia      -0.363931  Marine Coastal Fishing  2009         1658.0
# 4      Estonia      -0.363931  Marine Coastal Fishing  2010         1732.0
# ..         ...            ...                     ...   ...            ...
# 157  Indonesia       2.453376  Marine Coastal Fishing  2011      2265213.0
# 158  Indonesia       2.453376  Marine Coastal Fishing  2012      2278388.0
# 159  Indonesia       2.453376  Marine Coastal Fishing  2013      2164969.0
# 160  Indonesia       2.453376  Marine Coastal Fishing  2014      2210195.0
# 161  Indonesia       2.453376  Marine Coastal Fishing  2015      2275139.0
#
# [162 rows x 5 columns]

# %%
employment_Marine_Deep_Sea_Fishing = pd.merge(cosatline_df, Marine_Deep_Sea_Fishing, on=['Country'])
employment_Marine_Deep_Sea_Fishing
# Out:
#      Country  Coastline_std                 Economic  Year  Employees_Num
# 0    Estonia      -0.363931  Marine Deep-Sea Fishing  2006          475.0
# 1    Estonia      -0.363931  Marine Deep-Sea Fishing  2007          470.0
# 2    Estonia      -0.363931  Marine Deep-Sea Fishing  2008          465.0
# 3    Estonia      -0.363931  Marine Deep-Sea Fishing  2009          479.0
# 4    Estonia      -0.363931  Marine Deep-Sea Fishing  2010          474.0
# ..       ...            ...                      ...   ...            ...
# 93  Portugal      -0.474796  Marine Deep-Sea Fishing  2016          409.0
# 94  Portugal      -0.474796  Marine Deep-Sea Fishing  2017          435.0
# 95  Colombia      -0.396792  Marine Deep-Sea Fishing  2011           42.0
# 96  Colombia      -0.396792  Marine Deep-Sea Fishing  2012           42.0
# 97  Colombia      -0.396792  Marine Deep-Sea Fishing  2013           42.0
#
# [98 rows x 5 columns]

# %%
employment_Processing = pd.merge(cosatline_df, Processing_df, on=['Country'])
employment_Processing
# Out:
#        Country  Coastline_std    Economic  Year  Employees_Num
# 0      Estonia      -0.363931  Processing  2006         2507.0
# 1      Estonia      -0.363931  Processing  2007         2513.0
# 2      Estonia      -0.363931  Processing  2008         2090.0
# 3      Estonia      -0.363931  Processing  2009         1831.0
# 4      Estonia      -0.363931  Processing  2010         1772.0
# ..         ...            ...         ...   ...            ...
# 103   Colombia      -0.396792  Processing  2011        72000.0
# 104   Colombia      -0.396792  Processing  2012        72000.0
# 105   Colombia      -0.396792  Processing  2013        72000.0
# 106  Indonesia       2.453376  Processing  2014       346253.0
# 107  Indonesia       2.453376  Processing  2015       362741.0
#
# [108 rows x 5 columns]

# %%
employment_Unspecified_Fishing = pd.merge(cosatline_df, Unspecified_Fishing, on=['Country'])
employment_Unspecified_Fishing
# Out:
#       Country  Coastline_std             Economic  Year  Employees_Num
# 0      Mexico      -0.057671  Unspecified Fishing  2005        43007.0
# 1      Poland      -0.531224  Unspecified Fishing  2010         1409.0
# 2      Poland      -0.531224  Unspecified Fishing  2011         1386.0
# 3      Poland      -0.531224  Unspecified Fishing  2012         1577.0
# 4      Poland      -0.531224  Unspecified Fishing  2013         1543.0
# 5      Poland      -0.531224  Unspecified Fishing  2014         1333.0
# 6      Poland      -0.531224  Unspecified Fishing  2015         1222.0
# 7      Poland      -0.531224  Unspecified Fishing  2016         1180.0
# 8      Poland      -0.531224  Unspecified Fishing  2017         1166.0
# 9   Australia       2.730869  Unspecified Fishing  2005         7441.0
# 10  Australia       2.730869  Unspecified Fishing  2006         8235.0
# 11  Australia       2.730869  Unspecified Fishing  2007         6151.0
# ...

# %% [markdown]
# #### טבלאת צי הדיג, כלומר כמות הספינות וכמות הדגים (מה שאנחנו רוצים לחזות)

# %%
fishingf_df1 = pd.read_csv("Fishing fleet.csv")

# %%
fishingf_df2=fishingf_df1.drop(columns=['PowerCode','PowerCode Code','Reference Period Code','Reference Period','Flag Codes','YEAR','Flags','MEASURE','COUNTRY','FLEET','Unit Code'])

# %%
fishingf_df3=fishingf_df2.loc[(fishingf_df2.Country == "Australia")|(fishingf_df2.Country == "Estonia")|(fishingf_df2.Country == "Finland")|(fishingf_df2.Country == "Greece")|(fishingf_df2.Country == "Korea")|(fishingf_df2.Country == "Latvia")|(fishingf_df2.Country == "Mexico")|(fishingf_df2.Country == "Netherlands")|(fishingf_df2.Country == "Poland")|(fishingf_df2.Country == "Portugal")|(fishingf_df2.Country == "Sweden")|(fishingf_df2.Country == "Turkey")|(fishingf_df2.Country == "Argentina")|(fishingf_df2.Country == "Colombia")|(fishingf_df2.Country == "Indonesia"),:]

# %%
fishingf_df=fishingf_df3.loc[(fishingf_df3.Fleet == "Total vessels")]

# %%
fishingf_num=fishingf_df[fishingf_df.Unit=='Number']

# %%
fishingf_df.head()
# Out:
#      Country          Fleet            Measure  Year    Unit  Value
# 0  Australia  Total vessels  Number of vessels  2005  Number  590.0
# 1  Australia  Total vessels  Number of vessels  2006  Number  477.0
# 2  Australia  Total vessels  Number of vessels  2007  Number  374.0
# 3  Australia  Total vessels  Number of vessels  2008  Number  332.0
# 4  Australia  Total vessels  Number of vessels  2009  Number  332.0

# %%
fishingf_df
# Out:
#         Country          Fleet            Measure  Year    Unit    Value
# 0     Australia  Total vessels  Number of vessels  2005  Number    590.0
# 1     Australia  Total vessels  Number of vessels  2006  Number    477.0
# 2     Australia  Total vessels  Number of vessels  2007  Number    374.0
# 3     Australia  Total vessels  Number of vessels  2008  Number    332.0
# 4     Australia  Total vessels  Number of vessels  2009  Number    332.0
# ...         ...            ...                ...   ...     ...      ...
# 8086     Latvia  Total vessels      Gross tonnage  2013  Tonnes  29945.0
# 8087     Latvia  Total vessels      Gross tonnage  2014  Tonnes  19535.0
# 8088     Latvia  Total vessels      Gross tonnage  2015  Tonnes  24676.0
# 8089     Latvia  Total vessels      Gross tonnage  2016  Tonnes  28518.0
# 8090     Latvia  Total vessels      Gross tonnage  2017  Tonnes  27392.0
#
# [370 rows x 6 columns]

# %% [markdown]
# #### כמות הספינות (במספר)

# %%
fishingf_num.rename({'Value':'Vessels_Num'}, axis='columns', inplace=True)
fishingf_num
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#         Country          Fleet            Measure  Year    Unit  Vessels_Num
# 0     Australia  Total vessels  Number of vessels  2005  Number        590.0
# 1     Australia  Total vessels  Number of vessels  2006  Number        477.0
# 2     Australia  Total vessels  Number of vessels  2007  Number        374.0
# 3     Australia  Total vessels  Number of vessels  2008  Number        332.0
# 4     Australia  Total vessels  Number of vessels  2009  Number        332.0
# ...         ...            ...                ...   ...     ...          ...
# 8073     Latvia  Total vessels  Number of vessels  2013  Number        703.0
# ...

# %%
fishingf_ton=fishingf_df[fishingf_df.Unit!='Number']

# %% [markdown]
# #### (כמות הדגים (בטון

# %%
fishingf_ton.rename({'Value':'Fishes_Num'}, axis='columns', inplace=True)
fishingf_ton
# Out:
#         Country          Fleet        Measure  Year    Unit  Fishes_Num
# 13    Australia  Total vessels  Gross tonnage  2006  Tonnes     63555.0
# 14    Australia  Total vessels  Gross tonnage  2007  Tonnes     53458.0
# 15    Australia  Total vessels  Gross tonnage  2008  Tonnes     48828.0
# 16    Australia  Total vessels  Gross tonnage  2009  Tonnes     31932.0
# 17    Australia  Total vessels  Gross tonnage  2010  Tonnes     36365.0
# ...         ...            ...            ...   ...     ...         ...
# 8086     Latvia  Total vessels  Gross tonnage  2013  Tonnes     29945.0
# 8087     Latvia  Total vessels  Gross tonnage  2014  Tonnes     19535.0
# 8088     Latvia  Total vessels  Gross tonnage  2015  Tonnes     24676.0
# 8089     Latvia  Total vessels  Gross tonnage  2016  Tonnes     28518.0
# 8090     Latvia  Total vessels  Gross tonnage  2017  Tonnes     27392.0
#
# [179 rows x 6 columns]

# %% [markdown]
# #### איחוד בין כמות הספינות והדגים

# %%
fleet1 = pd.merge(fishingf_num, fishingf_ton, on=['Country', 'Year'])
fleet1
# Out:
#        Country        Fleet_x          Measure_x  Year  Unit_x  Vessels_Num  \
# 0    Australia  Total vessels  Number of vessels  2006  Number        477.0
# 1    Australia  Total vessels  Number of vessels  2007  Number        374.0
# 2    Australia  Total vessels  Number of vessels  2008  Number        332.0
# 3    Australia  Total vessels  Number of vessels  2009  Number        332.0
# 4    Australia  Total vessels  Number of vessels  2010  Number        318.0
# ..         ...            ...                ...   ...     ...          ...
# 174     Latvia  Total vessels  Number of vessels  2013  Number        703.0
# 175     Latvia  Total vessels  Number of vessels  2014  Number        700.0
# 176     Latvia  Total vessels  Number of vessels  2015  Number        686.0
# 177     Latvia  Total vessels  Number of vessels  2016  Number        679.0
# 178     Latvia  Total vessels  Number of vessels  2017  Number        675.0
#
#            Fleet_y      Measure_y  Unit_y  Fishes_Num
# ...

# %%
fleet=fleet1.drop(columns=['Fleet_x','Measure_x','Unit_x','Fleet_y','Measure_y','Unit_y'])
fleet
# Out:
#        Country  Year  Vessels_Num  Fishes_Num
# 0    Australia  2006        477.0     63555.0
# 1    Australia  2007        374.0     53458.0
# 2    Australia  2008        332.0     48828.0
# 3    Australia  2009        332.0     31932.0
# 4    Australia  2010        318.0     36365.0
# ..         ...   ...          ...         ...
# 174     Latvia  2013        703.0     29945.0
# 175     Latvia  2014        700.0     19535.0
# 176     Latvia  2015        686.0     24676.0
# 177     Latvia  2016        679.0     28518.0
# 178     Latvia  2017        675.0     27392.0
#
# [179 rows x 4 columns]

# %% [markdown]
# #### טבלאת כמות הדגים בבריכות דגים- כלומר פי'צר נוסף, איקס נוסף

# %%
Fishinland_df1 = pd.read_csv("Fish-Inland.csv")
Fishinland_df1.head()
# Out:
#   COUNTRY Country        SPECIES                    Species MEASURE Measure  \
# 0     CAN  Canada  SPECIES_TOTAL  ALL SPECIES - GRAND TOTAL     TON   Tonne
# 1     CAN  Canada  SPECIES_TOTAL  ALL SPECIES - GRAND TOTAL     TON   Tonne
# 2     CAN  Canada  SPECIES_TOTAL  ALL SPECIES - GRAND TOTAL     TON   Tonne
# 3     CAN  Canada  SPECIES_TOTAL  ALL SPECIES - GRAND TOTAL     TON   Tonne
# 4     CAN  Canada  SPECIES_TOTAL  ALL SPECIES - GRAND TOTAL     TON   Tonne
#
#    YEAR  Year Unit Code    Unit  PowerCode Code PowerCode  \
# 0  2005  2005     TONNE  Tonnes               0     Units
# 1  2006  2006     TONNE  Tonnes               0     Units
# 2  2007  2007     TONNE  Tonnes               0     Units
# 3  2008  2008     TONNE  Tonnes               0     Units
# 4  2009  2009     TONNE  Tonnes               0     Units
#
#    Reference Period Code  Reference Period  Value Flag Codes Flags
# 0                    NaN               NaN  32269        NaN   NaN
# ...

# %%
Fishinland_df2 =Fishinland_df1.drop(columns=['PowerCode','PowerCode Code','Reference Period Code','Reference Period','Flag Codes','YEAR','COUNTRY','Unit Code','Measure','MEASURE','Unit','SPECIES'])
Fishinland_df2
# Out:
#      Country                                            Species  Year  Value  \
# 0     Canada                          ALL SPECIES - GRAND TOTAL  2005  32269
# 1     Canada                          ALL SPECIES - GRAND TOTAL  2006  32234
# 2     Canada                          ALL SPECIES - GRAND TOTAL  2007  32303
# 3     Canada                          ALL SPECIES - GRAND TOTAL  2008  31063
# 4     Canada                          ALL SPECIES - GRAND TOTAL  2009  33023
# ...      ...                                                ...   ...    ...
# 8921  Mexico  Euro-American crayfishes nei [Astacidae, Camba...  2007     55
# 8922  Mexico  Euro-American crayfishes nei [Astacidae, Camba...  2008     73
# 8923  Mexico  Euro-American crayfishes nei [Astacidae, Camba...  2009     91
# 8924  Mexico  Euro-American crayfishes nei [Astacidae, Camba...  2010     88
# 8925  Mexico  Euro-American crayfishes nei [Astacidae, Camba...  2011     70
#
#      Flags
# 0      NaN
# 1      NaN
# ...

# %%
Fishinland_df2=Fishinland_df2.loc[(Fishinland_df2.Species =="ALL SPECIES - GRAND TOTAL")]
Fishinland_df2
# Out:
#       Country                    Species  Year  Value Flags
# 0      Canada  ALL SPECIES - GRAND TOTAL  2005  32269   NaN
# 1      Canada  ALL SPECIES - GRAND TOTAL  2006  32234   NaN
# 2      Canada  ALL SPECIES - GRAND TOTAL  2007  32303   NaN
# 3      Canada  ALL SPECIES - GRAND TOTAL  2008  31063   NaN
# 4      Canada  ALL SPECIES - GRAND TOTAL  2009  33023   NaN
# ...       ...                        ...   ...    ...   ...
# 5445  Austria  ALL SPECIES - GRAND TOTAL  2013    350   NaN
# 5446  Austria  ALL SPECIES - GRAND TOTAL  2014    350   NaN
# 5447  Austria  ALL SPECIES - GRAND TOTAL  2015    350   NaN
# 5448  Austria  ALL SPECIES - GRAND TOTAL  2016    350   NaN
# 5449  Austria  ALL SPECIES - GRAND TOTAL  2017    350   NaN
#
# [364 rows x 5 columns]

# %%
Fishinland_df2.rename({'Value':'Inland_Fish'}, axis='columns', inplace=True)  
Fishinland_df2
# Out:
#       Country                    Species  Year  Inland_Fish Flags
# 0      Canada  ALL SPECIES - GRAND TOTAL  2005        32269   NaN
# 1      Canada  ALL SPECIES - GRAND TOTAL  2006        32234   NaN
# 2      Canada  ALL SPECIES - GRAND TOTAL  2007        32303   NaN
# 3      Canada  ALL SPECIES - GRAND TOTAL  2008        31063   NaN
# 4      Canada  ALL SPECIES - GRAND TOTAL  2009        33023   NaN
# ...       ...                        ...   ...          ...   ...
# 5445  Austria  ALL SPECIES - GRAND TOTAL  2013          350   NaN
# 5446  Austria  ALL SPECIES - GRAND TOTAL  2014          350   NaN
# 5447  Austria  ALL SPECIES - GRAND TOTAL  2015          350   NaN
# 5448  Austria  ALL SPECIES - GRAND TOTAL  2016          350   NaN
# 5449  Austria  ALL SPECIES - GRAND TOTAL  2017          350   NaN
#
# [364 rows x 5 columns]

# %%
Fishinland_df2=Fishinland_df2.fillna({'Flags':'Flag'})
Fishinland_df2.head()
# Out:
#   Country                    Species  Year  Inland_Fish Flags
# 0  Canada  ALL SPECIES - GRAND TOTAL  2005        32269  Flag
# 1  Canada  ALL SPECIES - GRAND TOTAL  2006        32234  Flag
# 2  Canada  ALL SPECIES - GRAND TOTAL  2007        32303  Flag
# 3  Canada  ALL SPECIES - GRAND TOTAL  2008        31063  Flag
# 4  Canada  ALL SPECIES - GRAND TOTAL  2009        33023  Flag

# %% [markdown]
# 1-ערך אמיתי
# 0-ערך משוערך

# %%
Flags = pd.get_dummies(Fishinland_df2['Flags'],drop_first=True)
Flags
# Out:
#       Flag
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 5445     1
# 5446     1
# 5447     1
# 5448     1
# 5449     1
#
# [364 rows x 1 columns]

# %%
Inland = pd.concat([Fishinland_df2,Flags],axis=1)
Inland.head()
# Out:
#   Country                    Species  Year  Inland_Fish Flags  Flag
# 0  Canada  ALL SPECIES - GRAND TOTAL  2005        32269  Flag     1
# 1  Canada  ALL SPECIES - GRAND TOTAL  2006        32234  Flag     1
# 2  Canada  ALL SPECIES - GRAND TOTAL  2007        32303  Flag     1
# 3  Canada  ALL SPECIES - GRAND TOTAL  2008        31063  Flag     1
# 4  Canada  ALL SPECIES - GRAND TOTAL  2009        33023  Flag     1

# %%
Inland=Inland.drop(columns=['Flags','Species','Flag'])
Inland
# Out:
#       Country  Year  Inland_Fish
# 0      Canada  2005        32269
# 1      Canada  2006        32234
# 2      Canada  2007        32303
# 3      Canada  2008        31063
# 4      Canada  2009        33023
# ...       ...   ...          ...
# 5445  Austria  2013          350
# 5446  Austria  2014          350
# 5447  Austria  2015          350
# 5448  Austria  2016          350
# 5449  Austria  2017          350
#
# [364 rows x 3 columns]

# %%
End = pd.merge(Inland, fleet, on=['Country','Year'])
End
# Out:
#      Country  Year  Inland_Fish  Vessels_Num  Fishes_Num
# 0    Finland  2005        36268       3265.0    16947.68
# 1    Finland  2006        36513       3196.0    19093.34
# 2    Finland  2007        36513       3164.0    16113.27
# 3    Finland  2008        29312       3242.0    16165.65
# 4    Finland  2009        29312       3271.0    16397.18
# ..       ...   ...          ...          ...         ...
# 135   Latvia  2013          313        703.0    29945.00
# 136   Latvia  2014          272        700.0    19535.00
# 137   Latvia  2015          226        686.0    24676.00
# 138   Latvia  2016          243        679.0    28518.00
# 139   Latvia  2017          226        675.0    27392.00
#
# [140 rows x 5 columns]

# %%
y= End.Inland_Fish
End['Inland_Fish_std'] = standardNormalization(y)
End
# Out:
#      Country  Year  Inland_Fish  Vessels_Num  Fishes_Num  Inland_Fish_std
# 0    Finland  2005        36268       3265.0    16947.68         0.321203
# 1    Finland  2006        36513       3196.0    19093.34         0.327978
# 2    Finland  2007        36513       3164.0    16113.27         0.327978
# 3    Finland  2008        29312       3242.0    16165.65         0.128833
# 4    Finland  2009        29312       3271.0    16397.18         0.128833
# ..       ...   ...          ...          ...         ...              ...
# 135   Latvia  2013          313        703.0    29945.00        -0.673139
# 136   Latvia  2014          272        700.0    19535.00        -0.674272
# 137   Latvia  2015          226        686.0    24676.00        -0.675545
# 138   Latvia  2016          243        679.0    28518.00        -0.675074
# 139   Latvia  2017          226        675.0    27392.00        -0.675545
#
# [140 rows x 6 columns]

# %%
End=End.drop(columns=['Inland_Fish'])
End
# Out:
#      Country  Year  Vessels_Num  Fishes_Num  Inland_Fish_std
# 0    Finland  2005       3265.0    16947.68         0.321203
# 1    Finland  2006       3196.0    19093.34         0.327978
# 2    Finland  2007       3164.0    16113.27         0.327978
# 3    Finland  2008       3242.0    16165.65         0.128833
# 4    Finland  2009       3271.0    16397.18         0.128833
# ..       ...   ...          ...         ...              ...
# 135   Latvia  2013        703.0    29945.00        -0.673139
# 136   Latvia  2014        700.0    19535.00        -0.674272
# 137   Latvia  2015        686.0    24676.00        -0.675545
# 138   Latvia  2016        679.0    28518.00        -0.675074
# 139   Latvia  2017        675.0    27392.00        -0.675545
#
# [140 rows x 5 columns]

# %% [markdown]
# Aquaculture

# %%
End_Aquaculture = pd.merge(End, employment_Aquaculture, on=['Country','Year'])
End_Aquaculture =End_Aquaculture.drop(columns=['Economic'])
End_Aquaculture =End_Aquaculture[['Country','Year','Inland_Fish_std','Coastline_std','Vessels_Num','Fishes_Num','Employees_Num']]
End_Aquaculture
# Out:
#      Country  Year  Inland_Fish_std  Coastline_std  Vessels_Num  Fishes_Num  \
# 0    Finland  2005         0.321203      -0.504670       3265.0    16947.68
# 1    Finland  2006         0.327978      -0.504670       3196.0    19093.34
# 2    Finland  2007         0.327978      -0.504670       3164.0    16113.27
# 3    Finland  2009         0.128833      -0.504670       3271.0    16397.18
# 4    Finland  2010         0.116720      -0.504670       3366.0    16698.28
# ..       ...   ...              ...            ...          ...         ...
# 113   Latvia  2013        -0.673139      -0.544446        703.0    29945.00
# 114   Latvia  2014        -0.674272      -0.544446        700.0    19535.00
# 115   Latvia  2015        -0.675545      -0.544446        686.0    24676.00
# 116   Latvia  2016        -0.675074      -0.544446        679.0    28518.00
# 117   Latvia  2017        -0.675545      -0.544446        675.0    27392.00
#
#      Employees_Num
# 0            439.0
# ...

# %%
End_Aquaculture.corr()
# Out:
#                      Year  Inland_Fish_std  Coastline_std  Vessels_Num  \
# Year             1.000000         0.041415       0.071124    -0.040711
# Inland_Fish_std  0.041415         1.000000       0.289298     0.637773
# Coastline_std    0.071124         0.289298       1.000000     0.555822
# Vessels_Num     -0.040711         0.637773       0.555822     1.000000
# Fishes_Num      -0.010118         0.168195       0.450697     0.740503
# Employees_Num    0.100532         0.503140       0.308064     0.592110
#
#                  Fishes_Num  Employees_Num
# Year              -0.010118       0.100532
# Inland_Fish_std    0.168195       0.503140
# Coastline_std      0.450697       0.308064
# Vessels_Num        0.740503       0.592110
# Fishes_Num         1.000000       0.431244
# Employees_Num      0.431244       1.000000

# %% [markdown]
# Fishing Sector

# %%
End_Fishing_Sector = pd.merge(End, employment_Fishing_Sector, on=['Country','Year'])
End_Fishing_Sector =End_Fishing_Sector.drop(columns=['Economic'])
End_Fishing_Sector =End_Fishing_Sector[['Country','Year','Inland_Fish_std','Coastline_std','Vessels_Num','Fishes_Num','Employees_Num']]
End_Fishing_Sector
# Out:
#      Country  Year  Inland_Fish_std  Coastline_std  Vessels_Num  Fishes_Num  \
# 0    Finland  2005         0.321203      -0.504670       3265.0    16947.68
# 1    Finland  2006         0.327978      -0.504670       3196.0    19093.34
# 2    Finland  2007         0.327978      -0.504670       3164.0    16113.27
# 3    Finland  2008         0.128833      -0.504670       3242.0    16165.65
# 4    Finland  2009         0.128833      -0.504670       3271.0    16397.18
# ..       ...   ...              ...            ...          ...         ...
# 120   Latvia  2013        -0.673139      -0.544446        703.0    29945.00
# 121   Latvia  2014        -0.674272      -0.544446        700.0    19535.00
# 122   Latvia  2015        -0.675545      -0.544446        686.0    24676.00
# 123   Latvia  2016        -0.675074      -0.544446        679.0    28518.00
# 124   Latvia  2017        -0.675545      -0.544446        675.0    27392.00
#
#      Employees_Num
# 0           2755.0
# ...

# %%
End_Fishing_Sector.corr()
# Out:
#                      Year  Inland_Fish_std  Coastline_std  Vessels_Num  \
# Year             1.000000         0.031125       0.023822    -0.065919
# Inland_Fish_std  0.031125         1.000000       0.287636     0.634696
# Coastline_std    0.023822         0.287636       1.000000     0.568375
# Vessels_Num     -0.065919         0.634696       0.568375     1.000000
# Fishes_Num      -0.037737         0.169857       0.470418     0.746303
# Employees_Num    0.011833         0.716380       0.399418     0.671182
#
#                  Fishes_Num  Employees_Num
# Year              -0.037737       0.011833
# Inland_Fish_std    0.169857       0.716380
# Coastline_std      0.470418       0.399418
# Vessels_Num        0.746303       0.671182
# Fishes_Num         1.000000       0.298261
# Employees_Num      0.298261       1.000000

# %% [markdown]
# Inland Waters Fishing

# %%
End_Inland_Waters_Fishing = pd.merge(End, employment_Inland_Waters_Fishing, on=['Country','Year'])
End_Inland_Waters_Fishing =End_Inland_Waters_Fishing.drop(columns=['Economic'])
End_Inland_Waters_Fishing =End_Inland_Waters_Fishing[['Country','Year','Inland_Fish_std','Coastline_std','Vessels_Num','Fishes_Num','Employees_Num']]
End_Inland_Waters_Fishing
# Out:
#      Country  Year  Inland_Fish_std  Coastline_std  Vessels_Num  Fishes_Num  \
# 0    Finland  2005         0.321203      -0.504670       3265.0    16947.68
# 1    Finland  2006         0.327978      -0.504670       3196.0    19093.34
# 2    Finland  2007         0.327978      -0.504670       3164.0    16113.27
# 3    Finland  2008         0.128833      -0.504670       3242.0    16165.65
# 4    Finland  2009         0.128833      -0.504670       3271.0    16397.18
# ..       ...   ...              ...            ...          ...         ...
# 96    Latvia  2013        -0.673139      -0.544446        703.0    29945.00
# 97    Latvia  2014        -0.674272      -0.544446        700.0    19535.00
# 98    Latvia  2015        -0.675545      -0.544446        686.0    24676.00
# 99    Latvia  2016        -0.675074      -0.544446        679.0    28518.00
# 100   Latvia  2017        -0.675545      -0.544446        675.0    27392.00
#
#      Employees_Num
# 0            545.0
# ...

# %%
End_Inland_Waters_Fishing.corr()
# Out:
#                      Year  Inland_Fish_std  Coastline_std  Vessels_Num  \
# Year             1.000000         0.047773       0.069774    -0.080632
# Inland_Fish_std  0.047773         1.000000       0.320621     0.801005
# Coastline_std    0.069774         0.320621       1.000000     0.531101
# Vessels_Num     -0.080632         0.801005       0.531101     1.000000
# Fishes_Num       0.008589         0.418516       0.470093     0.703438
# Employees_Num    0.057132         0.030122      -0.049711    -0.056293
#
#                  Fishes_Num  Employees_Num
# Year               0.008589       0.057132
# Inland_Fish_std    0.418516       0.030122
# Coastline_std      0.470093      -0.049711
# Vessels_Num        0.703438      -0.056293
# Fishes_Num         1.000000      -0.082704
# Employees_Num     -0.082704       1.000000

# %% [markdown]
# Marine Coastal Fishing

# %%
End_Marine_Coastal_Fishing = pd.merge(End, employment_Marine_Coastal_Fishing, on=['Country','Year'])
End_Marine_Coastal_Fishing =End_Marine_Coastal_Fishing.drop(columns=['Economic'])
End_Marine_Coastal_Fishing=End_Marine_Coastal_Fishing[['Country','Year','Inland_Fish_std','Coastline_std','Vessels_Num','Fishes_Num','Employees_Num']]
End_Marine_Coastal_Fishing
# Out:
#      Country  Year  Inland_Fish_std  Coastline_std  Vessels_Num  Fishes_Num  \
# 0    Finland  2005         0.321203      -0.504670       3265.0    16947.68
# 1    Finland  2006         0.327978      -0.504670       3196.0    19093.34
# 2    Finland  2007         0.327978      -0.504670       3164.0    16113.27
# 3    Finland  2008         0.128833      -0.504670       3242.0    16165.65
# 4    Finland  2009         0.128833      -0.504670       3271.0    16397.18
# ..       ...   ...              ...            ...          ...         ...
# 120   Latvia  2013        -0.673139      -0.544446        703.0    29945.00
# 121   Latvia  2014        -0.674272      -0.544446        700.0    19535.00
# 122   Latvia  2015        -0.675545      -0.544446        686.0    24676.00
# 123   Latvia  2016        -0.675074      -0.544446        679.0    28518.00
# 124   Latvia  2017        -0.675545      -0.544446        675.0    27392.00
#
#      Employees_Num
# 0           2210.0
# ...

# %%
End_Marine_Coastal_Fishing.corr()
# Out:
#                      Year  Inland_Fish_std  Coastline_std  Vessels_Num  \
# Year             1.000000         0.031125       0.023822    -0.065919
# Inland_Fish_std  0.031125         1.000000       0.287636     0.634696
# Coastline_std    0.023822         0.287636       1.000000     0.568375
# Vessels_Num     -0.065919         0.634696       0.568375     1.000000
# Fishes_Num      -0.037737         0.169857       0.470418     0.746303
# Employees_Num   -0.006581         0.873262       0.547462     0.903303
#
#                  Fishes_Num  Employees_Num
# Year              -0.037737      -0.006581
# Inland_Fish_std    0.169857       0.873262
# Coastline_std      0.470418       0.547462
# Vessels_Num        0.746303       0.903303
# Fishes_Num         1.000000       0.486801
# Employees_Num      0.486801       1.000000

# %% [markdown]
# Marine Deep Sea Fishing

# %%
End_Marine_Deep_Sea_Fishing = pd.merge(End, employment_Marine_Deep_Sea_Fishing, on=['Country','Year'])
End_Marine_Deep_Sea_Fishing =End_Marine_Deep_Sea_Fishing.drop(columns=['Economic'])
End_Marine_Deep_Sea_Fishing=End_Marine_Deep_Sea_Fishing[['Country','Year','Inland_Fish_std','Coastline_std','Vessels_Num','Fishes_Num','Employees_Num']]
End_Marine_Deep_Sea_Fishing
# Out:
#    Country  Year  Inland_Fish_std  Coastline_std  Vessels_Num  Fishes_Num  \
# 0   Greece  2005        -0.638099       0.182756      18451.0    93532.83
# 1   Greece  2006        -0.642718       0.182756      18156.0    92449.20
# 2   Greece  2007        -0.641999       0.182756      17850.0    90712.28
# 3   Greece  2008        -0.642386       0.182756      17667.0    89042.82
# 4   Greece  2009        -0.655799       0.182756      17513.0    88252.41
# ..     ...   ...              ...            ...          ...         ...
# 67  Latvia  2013        -0.673139      -0.544446        703.0    29945.00
# 68  Latvia  2014        -0.674272      -0.544446        700.0    19535.00
# 69  Latvia  2015        -0.675545      -0.544446        686.0    24676.00
# 70  Latvia  2016        -0.675074      -0.544446        679.0    28518.00
# 71  Latvia  2017        -0.675545      -0.544446        675.0    27392.00
#
#     Employees_Num
# 0          2633.0
# 1          2563.0
# 2          4613.0
# ...

# %%
End_Marine_Deep_Sea_Fishing.corr()
# Out:
#                      Year  Inland_Fish_std  Coastline_std  Vessels_Num  \
# Year             1.000000         0.098331      -0.064230    -0.205585
# Inland_Fish_std  0.098331         1.000000       0.258659     0.704274
# Coastline_std   -0.064230         0.258659       1.000000     0.519573
# Vessels_Num     -0.205585         0.704274       0.519573     1.000000
# Fishes_Num      -0.234915         0.207703       0.378175     0.771012
# Employees_Num   -0.136312         0.821891       0.447562     0.773967
#
#                  Fishes_Num  Employees_Num
# Year              -0.234915      -0.136312
# Inland_Fish_std    0.207703       0.821891
# Coastline_std      0.378175       0.447562
# Vessels_Num        0.771012       0.773967
# Fishes_Num         1.000000       0.220187
# Employees_Num      0.220187       1.000000

# %% [markdown]
# Processing

# %%
End_Processing = pd.merge(End, employment_Processing, on=['Country','Year'])
End_Processing =End_Processing.drop(columns=['Economic'])
End_Processing=End_Processing[['Country','Year','Inland_Fish_std','Coastline_std','Vessels_Num','Fishes_Num','Employees_Num']]
End_Processing
# Out:
#     Country  Year  Inland_Fish_std  Coastline_std  Vessels_Num  Fishes_Num  \
# 0   Finland  2005         0.321203      -0.504670       3265.0    16947.68
# 1   Finland  2006         0.327978      -0.504670       3196.0    19093.34
# 2   Finland  2007         0.327978      -0.504670       3164.0    16113.27
# 3   Finland  2009         0.128833      -0.504670       3271.0    16397.18
# 4   Finland  2010         0.116720      -0.504670       3366.0    16698.28
# ..      ...   ...              ...            ...          ...         ...
# 82  Estonia  2013        -0.601263      -0.363931       1460.0    15216.94
# 83  Estonia  2014        -0.600654      -0.363931       1549.0    13457.00
# 84  Estonia  2015        -0.608315      -0.363931       1515.0    13338.71
# 85  Estonia  2016        -0.595759      -0.363931       1538.0    13472.34
# 86   Latvia  2017        -0.675545      -0.544446        675.0    27392.00
#
#     Employees_Num
# 0           865.0
# 1           824.0
# ...

# %%
End_Processing.corr()
# Out:
#                      Year  Inland_Fish_std  Coastline_std  Vessels_Num  \
# Year             1.000000        -0.273020      -0.009135    -0.241087
# Inland_Fish_std -0.273020         1.000000       0.072304     0.791104
# Coastline_std   -0.009135         0.072304       1.000000     0.465264
# Vessels_Num     -0.241087         0.791104       0.465264     1.000000
# Fishes_Num      -0.112118         0.567862       0.456368     0.486686
# Employees_Num    0.042902         0.242024      -0.134219     0.058793
#
#                  Fishes_Num  Employees_Num
# Year              -0.112118       0.042902
# Inland_Fish_std    0.567862       0.242024
# Coastline_std      0.456368      -0.134219
# Vessels_Num        0.486686       0.058793
# Fishes_Num         1.000000      -0.033637
# Employees_Num     -0.033637       1.000000

# %% [markdown]
# # מודלים סופיים

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

# %% [markdown]
# ## Marine Deep Sea Fishing

# %% [markdown]
# ### Y=Vessels

# %%
X = End_Marine_Deep_Sea_Fishing[['Inland_Fish_std','Coastline_std']]
y = End_Marine_Deep_Sea_Fishing.Vessels_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                      Results: Ordinary least squares
# ...
# Model:                 OLS                Adj. R-squared:       0.607
# Dependent Variable:    Vessels_Num        AIC:                  1659.1763
# Date:                  2020-01-27 10:43   BIC:                  1666.0063
# No. Observations:      72                 Log-Likelihood:       -826.59
# Df Model:              2                  F-statistic:          55.82
# Df Residuals:          69                 Prob (F-statistic):   3.81e-15
# R-squared:             0.618              Scale:                5.7247e+08
# --------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Inland fish vs Vessels

# %%
sb.lmplot(x='Inland_Fish_std',y='Vessels_Num', ci= None, data=End_Marine_Deep_Sea_Fishing, markers='.')
plt.gcf().suptitle('Inland Fish vs Vessels')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Vessels')

# %% [markdown]
# #### Costline vs Vessels

# %%
sb.lmplot(x='Coastline_std',y='Vessels_Num', ci= None, data=End_Marine_Deep_Sea_Fishing, markers='.')
plt.gcf().suptitle('Coastline vs Vessels')
# Out:
# Text(0.5, 0.98, 'Coastline vs Vessels')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [15068.05817951 49123.63126547]
# Mean squared error: 480241272.95
# Coefficient of determination: 0.71

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 480241272.94955903
# RMSE: 21914.40788498651
# MAE: 16122.492155796475

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.6106189860098965

# %% [markdown]
# ### Y=Employees

# %%
X = End_Marine_Deep_Sea_Fishing[['Inland_Fish_std','Coastline_std']]
y = End_Marine_Deep_Sea_Fishing.Employees_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                     Results: Ordinary least squares
# ...
# Model:                OLS               Adj. R-squared:      0.727
# Dependent Variable:   Employees_Num     AIC:                 1435.1728
# Date:                 2020-01-27 10:43  BIC:                 1442.0028
# No. Observations:     72                Log-Likelihood:      -714.59
# Df Model:             2                 F-statistic:         95.53
# Df Residuals:         69                Prob (F-statistic):  1.32e-20
# R-squared:            0.735             Scale:               2.5503e+07
# -----------------------------------------------------------------------
#                   Coef.    Std.Err.    t    P>|t|    [0.025    0.975]
# ...

# %% [markdown]
# #### Inland fish vs Employee

# %%
sb.lmplot(x='Inland_Fish_std',y='Employees_Num', ci= None, data=End_Marine_Deep_Sea_Fishing, markers='.')
plt.gcf().suptitle('Inland Fish vs Employees')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Employees')

# %% [markdown]
# #### Coastline vs Employee

# %%
sb.lmplot(x='Coastline_std',y='Employees_Num', ci= None, data=End_Marine_Deep_Sea_Fishing, markers='.')
plt.gcf().suptitle('Coastline vs Employees')
# Out:
# Text(0.5, 0.98, 'Coastline vs Employees')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [4485.95803341 8201.18855762]
# Mean squared error: 43115779.67
# Coefficient of determination: 0.69

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 43115779.67433813
# RMSE: 6566.260707155796
# MAE: 3718.609081269661

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.7097343503519417

# %% [markdown]
# ### Y=Fishes

# %%
X = End_Marine_Deep_Sea_Fishing[['Inland_Fish_std','Coastline_std']]
y = End_Marine_Deep_Sea_Fishing.Fishes_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                       Results: Ordinary least squares
# ...
# Model:                 OLS                 Adj. R-squared:        0.131
# Dependent Variable:    Fishes_Num          AIC:                   1948.0266
# Date:                  2020-01-27 10:43    BIC:                   1954.8566
# No. Observations:      72                  Log-Likelihood:        -971.01
# Df Model:              2                   F-statistic:           6.375
# Df Residuals:          69                  Prob (F-statistic):    0.00288
# R-squared:             0.156               Scale:                 3.1627e+10
# ----------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Inland fish vs Fishes

# %%
sb.lmplot(x='Inland_Fish_std',y='Fishes_Num', ci= None, data=End_Marine_Deep_Sea_Fishing, markers='.')
plt.gcf().suptitle('Inland Fish vs Fishes')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Fishes')

# %% [markdown]
# #### Coastline vs Fishes

# %%
sb.lmplot(x='Coastline_std',y='Fishes_Num', ci= None, data=End_Marine_Deep_Sea_Fishing, markers='.')
plt.gcf().suptitle('Coastline vs Fishes')
# Out:
# Text(0.5, 0.98, 'Coastline vs Fishes')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 17931.59687179 236502.77242405]
# Mean squared error: 22792413661.98
# Coefficient of determination: 0.19

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 22792413661.97919
# RMSE: 150971.56573997368
# MAE: 94174.17587133292

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.15527786414504274

# %% [markdown]
# ## Marine Coastal Fishing

# %% [markdown]
# ### Y=Vessels

# %%
X = End_Marine_Coastal_Fishing[['Inland_Fish_std','Coastline_std']]
y = End_Marine_Coastal_Fishing.Vessels_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                      Results: Ordinary least squares
# ...
# Model:                OLS                Adj. R-squared:       0.558
# Dependent Variable:   Vessels_Num        AIC:                  2851.7111
# Date:                 2020-01-27 10:43   BIC:                  2860.1961
# No. Observations:     125                Log-Likelihood:       -1422.9
# Df Model:             2                  F-statistic:          79.27
# Df Residuals:         122                Prob (F-statistic):   8.72e-23
# R-squared:            0.565              Scale:                4.6248e+08
# -------------------------------------------------------------------------
#                   Coef.     Std.Err.    t    P>|t|    [0.025     0.975]
# ...

# %% [markdown]
# #### Inland fish vs Vessels

# %%
sb.lmplot(x='Inland_Fish_std',y='Vessels_Num', ci= None, data=End_Marine_Coastal_Fishing, markers='.')
plt.gcf().suptitle('Inland Fish vs Vessels')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Vessels')

# %% [markdown]
# #### Costline vs Vessels

# %%
sb.lmplot(x='Coastline_std',y='Vessels_Num', ci= None, data=End_Marine_Coastal_Fishing, markers='.')
plt.gcf().suptitle('Coastline vs Vessels')
# Out:
# Text(0.5, 0.98, 'Coastline vs Vessels')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [16020.95709969 52095.08229694]
# Mean squared error: 496907803.64
# Coefficient of determination: 0.50

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 496907803.63965076
# RMSE: 22291.428927721317
# MAE: 15485.199567078733

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.5634142349139108

# %% [markdown]
# ### Y=Employees

# %%
X = End_Marine_Coastal_Fishing[['Inland_Fish_std','Coastline_std']]
y = End_Marine_Coastal_Fishing.Employees_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                      Results: Ordinary least squares
# ...
# Model:                OLS                Adj. R-squared:       0.856
# Dependent Variable:   Employees_Num      AIC:                  2864.2445
# Date:                 2020-01-27 10:43   BIC:                  2872.7295
# No. Observations:     125                Log-Likelihood:       -1429.1
# Df Model:             2                  F-statistic:          369.4
# Df Residuals:         122                Prob (F-statistic):   1.72e-52
# R-squared:            0.858              Scale:                5.1125e+08
# -------------------------------------------------------------------------
#                   Coef.     Std.Err.    t    P>|t|    [0.025     0.975]
# ...

# %% [markdown]
# #### Inland fish vs Employee

# %%
sb.lmplot(x='Inland_Fish_std',y='Employees_Num', ci= None, data=End_Marine_Coastal_Fishing, markers='.')
plt.gcf().suptitle('Inland Fish vs Employees')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Employees')

# %% [markdown]
# #### Coastline vs Employee

# %%
sb.lmplot(x='Coastline_std',y='Employees_Num', ci= None, data=End_Marine_Coastal_Fishing, markers='.')
plt.gcf().suptitle('Coastline vs Employees')
# Out:
# Text(0.5, 0.98, 'Coastline vs Employees')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [43749.68687347 76791.99531638]
# Mean squared error: 514936738.35
# Coefficient of determination: 0.81

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 514936738.34903353
# RMSE: 22692.21757230953
# MAE: 18641.068120055457

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.8579443065776587

# %% [markdown]
# ### Y=Fishes

# %%
X = End_Marine_Coastal_Fishing[['Inland_Fish_std','Coastline_std']]
y = End_Marine_Coastal_Fishing.Fishes_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                        Results: Ordinary least squares
# ...
# Model:                  OLS                 Adj. R-squared:        0.210
# Dependent Variable:     Fishes_Num          AIC:                   3339.1353
# Date:                   2020-01-27 10:43    BIC:                   3347.6203
# No. Observations:       125                 Log-Likelihood:        -1666.6
# Df Model:               2                   F-statistic:           17.47
# Df Residuals:           122                 Prob (F-statistic):    2.14e-07
# R-squared:              0.223               Scale:                 2.2834e+10
# -----------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Inland fish vs Fishes

# %%
sb.lmplot(x='Inland_Fish_std',y='Fishes_Num', ci= None, data=End_Marine_Coastal_Fishing, markers='.')
plt.gcf().suptitle('Inland Fish vs Fishes')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Fishes')

# %% [markdown]
# #### Coastline vs Fishes

# %%
sb.lmplot(x='Coastline_std',y='Fishes_Num', ci= None, data=End_Marine_Coastal_Fishing, markers='.')
plt.gcf().suptitle('Coastline vs Fishes')
# Out:
# Text(0.5, 0.98, 'Coastline vs Fishes')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 13706.60133129 281331.33287968]
# Mean squared error: 27317381296.20
# Coefficient of determination: 0.21

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 27317381296.200245
# RMSE: 165279.7062442944
# MAE: 99208.62497997303

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.21728069655200433

# %% [markdown]
# ## Fishing Sector

# %% [markdown]
# ### Y=Vessels

# %%
X = End_Fishing_Sector[['Inland_Fish_std','Coastline_std']]
y = End_Fishing_Sector.Vessels_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                      Results: Ordinary least squares
# ...
# Model:                OLS                Adj. R-squared:       0.558
# Dependent Variable:   Vessels_Num        AIC:                  2851.7111
# Date:                 2020-01-27 10:43   BIC:                  2860.1961
# No. Observations:     125                Log-Likelihood:       -1422.9
# Df Model:             2                  F-statistic:          79.27
# Df Residuals:         122                Prob (F-statistic):   8.72e-23
# R-squared:            0.565              Scale:                4.6248e+08
# -------------------------------------------------------------------------
#                   Coef.     Std.Err.    t    P>|t|    [0.025     0.975]
# ...

# %% [markdown]
# #### Inland fish vs Vessels

# %%
sb.lmplot(x='Inland_Fish_std',y='Vessels_Num', ci= None, data=End_Fishing_Sector, markers='.')
plt.gcf().suptitle('Inland Fish vs Vessels')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Vessels')

# %% [markdown]
# #### Costline vs Vessels

# %%
sb.lmplot(x='Coastline_std',y='Vessels_Num', ci= None, data=End_Fishing_Sector, markers='.')
plt.gcf().suptitle('Coastline vs Vessels')
# Out:
# Text(0.5, 0.98, 'Coastline vs Vessels')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [16020.95709969 52095.08229694]
# Mean squared error: 496907803.64
# Coefficient of determination: 0.50

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 496907803.63965076
# RMSE: 22291.428927721317
# MAE: 15485.199567078733

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.5634142349139108

# %% [markdown]
# ### Y=Employees

# %%
X = End_Fishing_Sector[['Inland_Fish_std','Coastline_std']]
y = End_Fishing_Sector.Employees_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                       Results: Ordinary least squares
# ...
# Model:                  OLS                Adj. R-squared:       0.547
# Dependent Variable:     Employees_Num      AIC:                  3097.4849
# Date:                   2020-01-27 10:43   BIC:                  3105.9698
# No. Observations:       125                Log-Likelihood:       -1545.7
# Df Model:               2                  F-statistic:          75.76
# Df Residuals:           122                Prob (F-statistic):   4.09e-22
# R-squared:              0.554              Scale:                3.3037e+09
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Inland fish vs Employee

# %%
sb.lmplot(x='Inland_Fish_std',y='Employees_Num', ci= None, data=End_Fishing_Sector, markers='.')
plt.gcf().suptitle('Inland Fish vs Employees')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Employees')

# %% [markdown]
# #### Coastline vs Employee

# %%
sb.lmplot(x='Coastline_std',y='Employees_Num', ci= None, data=End_Fishing_Sector, markers='.')
plt.gcf().suptitle('Coastline vs Employees')
# Out:
# Text(0.5, 0.98, 'Coastline vs Employees')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [52394.22946883 73113.51345719]
# Mean squared error: 3503235942.88
# Coefficient of determination: 0.46

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 3503235942.881782
# RMSE: 59188.14022151551
# MAE: 30791.7879787079

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.5537440295422671

# %% [markdown]
# ### Y=Fishes

# %%
X = End_Fishing_Sector[['Inland_Fish_std','Coastline_std']]
y = End_Fishing_Sector.Fishes_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                        Results: Ordinary least squares
# ...
# Model:                  OLS                 Adj. R-squared:        0.210
# Dependent Variable:     Fishes_Num          AIC:                   3339.1353
# Date:                   2020-01-27 10:43    BIC:                   3347.6203
# No. Observations:       125                 Log-Likelihood:        -1666.6
# Df Model:               2                   F-statistic:           17.47
# Df Residuals:           122                 Prob (F-statistic):    2.14e-07
# R-squared:              0.223               Scale:                 2.2834e+10
# -----------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Inland fish vs Fishes

# %%
sb.lmplot(x='Inland_Fish_std',y='Fishes_Num', ci= None, data=End_Fishing_Sector, markers='.')
plt.gcf().suptitle('Inland Fish vs Fishes')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Fishes')

# %% [markdown]
# #### Coastline vs Fishes

# %%
sb.lmplot(x='Coastline_std',y='Fishes_Num', ci= None, data=End_Fishing_Sector, markers='.')
plt.gcf().suptitle('Coastline vs Fishes')
# Out:
# Text(0.5, 0.98, 'Coastline vs Fishes')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 13706.60133129 281331.33287968]
# Mean squared error: 27317381296.20
# Coefficient of determination: 0.21

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 27317381296.200245
# RMSE: 165279.7062442944
# MAE: 99208.62497997303

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.21728069655200433

# %% [markdown]
# ## Inland Waters Fishing

# %% [markdown]
# ### Y=Vessels

# %%
X = End_Inland_Waters_Fishing[['Inland_Fish_std','Coastline_std']]
y = End_Inland_Waters_Fishing.Vessels_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                      Results: Ordinary least squares
# ...
# Model:                OLS                Adj. R-squared:       0.720
# Dependent Variable:   Vessels_Num        AIC:                  2250.0998
# Date:                 2020-01-27 10:43   BIC:                  2257.9452
# No. Observations:     101                Log-Likelihood:       -1122.0
# Df Model:             2                  F-statistic:          129.5
# Df Residuals:         98                 Prob (F-statistic):   3.10e-28
# R-squared:            0.725              Scale:                2.6923e+08
# -------------------------------------------------------------------------
#                   Coef.     Std.Err.    t    P>|t|    [0.025     0.975]
# ...

# %% [markdown]
# #### Inland fish vs Vessels

# %%
sb.lmplot(x='Inland_Fish_std',y='Vessels_Num', ci= None, data=End_Inland_Waters_Fishing, markers='.')
plt.gcf().suptitle('Inland Fish vs Vessels')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Vessels')

# %% [markdown]
# #### Costline vs Vessels

# %%
sb.lmplot(x='Coastline_std',y='Vessels_Num', ci= None, data=End_Inland_Waters_Fishing, markers='.')
plt.gcf().suptitle('Coastline vs Vessels')
# Out:
# Text(0.5, 0.98, 'Coastline vs Vessels')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [17923.43058038 39492.10877343]
# Mean squared error: 166856914.58
# Coefficient of determination: 0.81

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 166856914.5782076
# RMSE: 12917.310655790841
# MAE: 10392.91854092555

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.7234066825388437

# %% [markdown]
# ### Y=Employees

# %%
X = End_Inland_Waters_Fishing[['Inland_Fish_std','Coastline_std']]
y = End_Inland_Waters_Fishing.Employees_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                       Results: Ordinary least squares
# ...
# Model:                 OLS                 Adj. R-squared:        -0.015
# Dependent Variable:    Employees_Num       AIC:                   2511.1960
# Date:                  2020-01-27 10:43    BIC:                   2519.0414
# No. Observations:      101                 Log-Likelihood:        -1252.6
# Df Model:              2                   F-statistic:           0.2381
# Df Residuals:          98                  Prob (F-statistic):    0.789
# R-squared:             0.005               Scale:                 3.5713e+09
# ----------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Inland fish vs Employee

# %%
sb.lmplot(x='Inland_Fish_std',y='Employees_Num', ci= None, data=End_Inland_Waters_Fishing, markers='.')
plt.gcf().suptitle('Inland Fish vs Employees')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Employees')

# %% [markdown]
# #### Coastline vs Employee

# %%
sb.lmplot(x='Coastline_std',y='Employees_Num', ci= None, data=End_Inland_Waters_Fishing, markers='.')
plt.gcf().suptitle('Coastline vs Employees')
# Out:
# Text(0.5, 0.98, 'Coastline vs Employees')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 2245.15628925 -5941.59801877]
# Mean squared error: 7557724061.92
# Coefficient of determination: -0.04

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 7557724061.9174
# RMSE: 86935.17160457786
# MAE: 26245.961652165573

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: -0.0055018821208663304

# %% [markdown]
# ### Y=Fishes

# %%
X = End_Inland_Waters_Fishing[['Inland_Fish_std','Coastline_std']]
y = End_Inland_Waters_Fishing.Fishes_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                       Results: Ordinary least squares
# ...
# Model:                 OLS                 Adj. R-squared:        0.287
# Dependent Variable:    Fishes_Num          AIC:                   2616.7991
# Date:                  2020-01-27 10:44    BIC:                   2624.6445
# No. Observations:      101                 Log-Likelihood:        -1305.4
# Df Model:              2                   F-statistic:           21.09
# Df Residuals:          98                  Prob (F-statistic):    2.41e-08
# R-squared:             0.301               Scale:                 1.0160e+10
# ----------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Inland fish vs Fishes

# %%
sb.lmplot(x='Inland_Fish_std',y='Fishes_Num', ci= None, data=End_Inland_Waters_Fishing, markers='.')
plt.gcf().suptitle('Inland Fish vs Fishes')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Fishes')

# %% [markdown]
# #### Coastline vs Fishes

# %%
sb.lmplot(x='Coastline_std',y='Fishes_Num', ci= None, data=End_Inland_Waters_Fishing, markers='.')
plt.gcf().suptitle('Coastline vs Fishes')
# Out:
# Text(0.5, 0.98, 'Coastline vs Fishes')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 30373.70231212 177695.05124738]
# Mean squared error: 2298800183.13
# Coefficient of determination: 0.63

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 2298800183.129595
# RMSE: 47945.804645762226
# MAE: 38596.97091294186

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.3007866956056878

# %% [markdown]
# ## Aquaculture

# %% [markdown]
# ### Y=Vessels

# %%
X = End_Aquaculture[['Inland_Fish_std','Coastline_std']]
y = End_Aquaculture.Vessels_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                      Results: Ordinary least squares
# ...
# Model:                OLS                Adj. R-squared:       0.550
# Dependent Variable:   Vessels_Num        AIC:                  2698.8106
# Date:                 2020-01-27 10:44   BIC:                  2707.1226
# No. Observations:     118                Log-Likelihood:       -1346.4
# Df Model:             2                  F-statistic:          72.36
# Df Residuals:         115                Prob (F-statistic):   4.53e-21
# R-squared:            0.557              Scale:                4.8921e+08
# -------------------------------------------------------------------------
#                   Coef.     Std.Err.    t    P>|t|    [0.025     0.975]
# ...

# %% [markdown]
# #### Inland fish vs Vessels

# %%
sb.lmplot(x='Inland_Fish_std',y='Vessels_Num', ci= None, data=End_Aquaculture, markers='.')
plt.gcf().suptitle('Inland Fish vs Vessels')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Vessels')

# %% [markdown]
# #### Costline vs Vessels

# %%
sb.lmplot(x='Coastline_std',y='Vessels_Num', ci= None, data=End_Aquaculture, markers='.')
plt.gcf().suptitle('Coastline vs Vessels')
# Out:
# Text(0.5, 0.98, 'Coastline vs Vessels')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [15176.54481379 57815.24860728]
# Mean squared error: 442321691.48
# Coefficient of determination: 0.63

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 442321691.4844849
# RMSE: 21031.445301844687
# MAE: 16453.141522417343

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.556602235559766

# %% [markdown]
# ### Y=Employees

# %%
X = End_Aquaculture[['Inland_Fish_std','Coastline_std']]
y = End_Aquaculture.Employees_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                     Results: Ordinary least squares
# ...
# Model:                 OLS               Adj. R-squared:      0.269
# Dependent Variable:    Employees_Num     AIC:                 2659.6568
# Date:                  2020-01-27 10:44  BIC:                 2667.9688
# No. Observations:      118               Log-Likelihood:      -1326.8
# Df Model:              2                 F-statistic:         22.58
# Df Residuals:          115               Prob (F-statistic):  5.35e-09
# R-squared:             0.282             Scale:               3.5107e+08
# ------------------------------------------------------------------------
#                   Coef.     Std.Err.   t    P>|t|    [0.025     0.975]
# ...

# %% [markdown]
# #### Inland fish vs Employee

# %%
sb.lmplot(x='Inland_Fish_std',y='Employees_Num', ci= None, data=End_Aquaculture, markers='.')
plt.gcf().suptitle('Inland Fish vs Employees')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Employees')

# %% [markdown]
# #### Coastline vs Employee

# %%
sb.lmplot(x='Coastline_std',y='Employees_Num', ci= None, data=End_Aquaculture, markers='.')
plt.gcf().suptitle('Coastline vs Employees')
# Out:
# Text(0.5, 0.98, 'Coastline vs Employees')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 9555.42759294 18140.93870412]
# Mean squared error: 314227063.65
# Coefficient of determination: 0.31

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 314227063.64672685
# RMSE: 17726.450960266324
# MAE: 10520.280549892377

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.28019446151815586

# %% [markdown]
# ### Y=Fishes

# %%
X = End_Aquaculture[['Inland_Fish_std','Coastline_std']]
y = End_Aquaculture.Fishes_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                        Results: Ordinary least squares
# ...
# Model:                  OLS                 Adj. R-squared:        0.191
# Dependent Variable:     Fishes_Num          AIC:                   3158.6789
# Date:                   2020-01-27 10:44    BIC:                   3166.9910
# No. Observations:       118                 Log-Likelihood:        -1576.3
# Df Model:               2                   F-statistic:           14.80
# Df Residuals:           115                 Prob (F-statistic):    1.91e-06
# R-squared:              0.205               Scale:                 2.4100e+10
# -----------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Inland fish vs Fishes

# %%
sb.lmplot(x='Inland_Fish_std',y='Fishes_Num', ci= None, data=End_Aquaculture, markers='.')
plt.gcf().suptitle('Inland Fish vs Fishes')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Fishes')

# %% [markdown]
# #### Coastline vs Fishes

# %%
sb.lmplot(x='Coastline_std',y='Fishes_Num', ci= None, data=End_Aquaculture, markers='.')
plt.gcf().suptitle('Coastline vs Fishes')
# Out:
# Text(0.5, 0.98, 'Coastline vs Fishes')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [  2127.12327013 330705.71573743]
# Mean squared error: 18808525179.86
# Coefficient of determination: 0.21

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 18808525179.85966
# RMSE: 137144.1766166528
# MAE: 82616.32750229022

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.20331000089289916

# %% [markdown]
# ##  Fleet and Inland Fish

# %%
Fleet_InlandFish = pd.merge(End, cosatline_df, on=['Country'])

# %%
Fleet_InlandFish=Fleet_InlandFish [['Country','Year','Inland_Fish_std','Coastline_std','Vessels_Num','Fishes_Num']]
Fleet_InlandFish
# Out:
#      Country  Year  Inland_Fish_std  Coastline_std  Vessels_Num  Fishes_Num
# 0    Finland  2005         0.321203      -0.504670       3265.0    16947.68
# 1    Finland  2006         0.327978      -0.504670       3196.0    19093.34
# 2    Finland  2007         0.327978      -0.504670       3164.0    16113.27
# 3    Finland  2008         0.128833      -0.504670       3242.0    16165.65
# 4    Finland  2009         0.128833      -0.504670       3271.0    16397.18
# ..       ...   ...              ...            ...          ...         ...
# 135   Latvia  2013        -0.673139      -0.544446        703.0    29945.00
# 136   Latvia  2014        -0.674272      -0.544446        700.0    19535.00
# 137   Latvia  2015        -0.675545      -0.544446        686.0    24676.00
# 138   Latvia  2016        -0.675074      -0.544446        679.0    28518.00
# 139   Latvia  2017        -0.675545      -0.544446        675.0    27392.00
#
# [140 rows x 6 columns]

# %%
Fleet_InlandFish.corr()
# Out:
#                      Year  Inland_Fish_std  Coastline_std  Vessels_Num  \
# Year             1.000000         0.032264       0.025268    -0.053246
# Inland_Fish_std  0.032264         1.000000       0.286501     0.619180
# Coastline_std    0.025268         0.286501       1.000000     0.582060
# Vessels_Num     -0.053246         0.619180       0.582060     1.000000
# Fishes_Num      -0.026684         0.164972       0.487253     0.762232
#
#                  Fishes_Num
# Year              -0.026684
# Inland_Fish_std    0.164972
# Coastline_std      0.487253
# Vessels_Num        0.762232
# Fishes_Num         1.000000

# %%
X = Fleet_InlandFish[['Inland_Fish_std','Coastline_std']]
y = Fleet_InlandFish .Vessels_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                      Results: Ordinary least squares
# ...
# Model:                OLS                Adj. R-squared:       0.555
# Dependent Variable:   Vessels_Num        AIC:                  3187.0909
# Date:                 2020-01-27 10:44   BIC:                  3195.9159
# No. Observations:     140                Log-Likelihood:       -1590.5
# Df Model:             2                  F-statistic:          87.81
# Df Residuals:         137                Prob (F-statistic):   2.86e-25
# R-squared:            0.562              Scale:                4.4158e+08
# -------------------------------------------------------------------------
#                   Coef.     Std.Err.    t    P>|t|    [0.025     0.975]
# ...

# %% [markdown]
# #### Inland fish vs Vessels

# %%
sb.lmplot(x='Inland_Fish_std',y='Vessels_Num', ci= None, data=Fleet_InlandFish, markers='.')
plt.gcf().suptitle('Inland Fish vs Vessels')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Vessels')

# %% [markdown]
# #### Costline vs Vessels

# %%
sb.lmplot(x='Coastline_std',y='Vessels_Num', ci= None, data=Fleet_InlandFish, markers='.')
plt.gcf().suptitle('Coastline vs Vessels')
# Out:
# Text(0.5, 0.98, 'Coastline vs Vessels')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [16203.488069   48493.99312555]
# Mean squared error: 622233296.63
# Coefficient of determination: 0.51

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 622233296.6258856
# RMSE: 24944.60455942097
# MAE: 17674.190458368408

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.5539438138444814

# %% [markdown]
# ### Y=Fishes

# %%
X = Fleet_InlandFish[['Inland_Fish_std','Coastline_std']]
y = Fleet_InlandFish.Fishes_Num
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1234)

# %%
diabetes = datasets.load_diabetes()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
p_values = est2.summary2()
p_values
# Out:
# C:\Users\sielf\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                        Results: Ordinary least squares
# ...
# Model:                  OLS                 Adj. R-squared:        0.227
# Dependent Variable:     Fishes_Num          AIC:                   3735.2202
# Date:                   2020-01-27 10:44    BIC:                   3744.0452
# No. Observations:       140                 Log-Likelihood:        -1864.6
# Df Model:               2                   F-statistic:           21.41
# Df Residuals:           137                 Prob (F-statistic):    8.12e-09
# R-squared:              0.238               Scale:                 2.2149e+10
# -----------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Inland fish vs Fishes

# %%
sb.lmplot(x='Inland_Fish_std',y='Fishes_Num', ci= None, data=End_Processing, markers='.')
plt.gcf().suptitle('Inland Fish vs Fishes')
# Out:
# Text(0.5, 0.98, 'Inland Fish vs Fishes')

# %% [markdown]
# #### Coastline vs Fishes

# %%
sb.lmplot(x='Coastline_std',y='Fishes_Num', ci= None, data=Fleet_InlandFish, markers='.')
plt.gcf().suptitle('Coastline vs Fishes')
# Out:
# Text(0.5, 0.98, 'Coastline vs Fishes')

# %% [markdown]
# ### Regression

# %%
regr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_pred = regr.predict(X_test)
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 19189.95031184 255506.00108628]
# Mean squared error: 31963842501.23
# Coefficient of determination: 0.15

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MSE: 31963842501.233376
# RMSE: 178784.34635401773
# MAE: 103177.29670944034

# %%
print ("R-squared:" ,regr.score(X, y))
# Out:
# R-squared: 0.21026006214066606
